# %%
# %matplotlib inline
from python_script.fig_1_4_choose_order import main as main_1_4
from python_script.under_good_over_fitting import main as main_under_good_over_fitting
from python_script.fig_1_2_polynomial_curve_fitting import main as main_1_2

# %%
main_1_2()

# %%
main_under_good_over_fitting()

# %%
main_1_4()
