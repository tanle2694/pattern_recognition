# %%
# %matplotlib inline
import numpy as np 
from python_script.fig_1_4_choose_order import main as main_1_4
from python_script.under_good_over_fitting import main as main_under_good_over_fitting
from python_script.fig_1_2_polynomial_curve_fitting import main as main_1_2
from python_script.fig_1_5_graph_of_ERMS import main as main_1_5
from python_script.table_1_1_coeff_w import main as main_tb_1_1
from python_script.fig_1_6_use_more_data import main as main_1_6
from python_script.fig_1_7_diff_l2 import main as main_1_7
from python_script.fig_1_8_rmse_lamda import main as main_1_8
from python_script.fig_1_12_probability_density import main as main_1_12
np.random.seed(1234)

# %%
main_1_2()

# %%
main_under_good_over_fitting()

# %%
main_1_4()

# %%
main_1_5()

# %%
main_tb_1_1()
# Out:
#     M=0      M=1       M=6           M=9
# w_0   0        0         0      0.000000
# w_1     -1.88016   6.47207      7.237619
# w_2                6.49803    -22.323939
# w_3               -89.6095    269.747512
# w_4                128.273  -1986.719013
# w_5               -51.7401   6722.377380
# w_6               0.204143 -12496.841890
# w_7                         13258.484167
# w_8                         -7512.595683
# w_9                          1760.795136

# %%
main_1_6()
# Out:
# No handles with labels found to put in legend.

# %%
main_1_7()

# %%
main_1_8()

# %%
main_1_12()
# Out:
# (550,)
